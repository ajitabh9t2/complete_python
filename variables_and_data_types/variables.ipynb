# %%
print('Hello World')
# Out:
# Hello World

# %%
print(2+2)
# Out:
# 4

# %%
name = "Ravi"
age = 20
height = 5.8

print(name)
print(age)
print(height)
# Out:
# Ravi
# 20
# 5.8

# %%
# String
city = "Delhi"

# Integer
pincode = 110001

# Float
temperature = 36.5

# Boolean
is_raining = False

print(city, pincode, temperature, is_raining)
# Out:
# Delhi 110001 36.5 False
